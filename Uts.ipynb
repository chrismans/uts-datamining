# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# %%
dataset = pd.read_csv("dataset_uts.csv",';' ,encoding='utf-8')
# Split the dataset by class values, returns a dictionary
def separate_by_class(dataset):
	separated = dict()
	for i in range(len(dataset)):
		vector = dataset[i]
		class_value = vector[-1]
		if (class_value not in separated):
			separated[class_value] = list()
		separated[class_value].append(vector)
	return separated
dataset.iloc[:,:5]
# Out:
#    No   Warna     Bulu Makanan Kesukaan Jenis
# 0   1   Hitam  Panjang           Wortel     A
# 1   2   Putih  Panjang           Wortel     A
# 2   3  Coklat   Pendek         Kangkung     B
# 3   4   Hitam   Pendek         Kangkung     B
# 4   5   Hitam   Gimbal           Rumput     C
# 5   6  Coklat   Gimbal           Rumput     A
# 6   7  Coklat  Panjang           Rumput     B
# 7   8   Putih   Pendek           Wortel     B
# 8   9   Putih   Pendek         Kangkung     C
# 9  10  Coklat   Gimbal         Kangkung     C
